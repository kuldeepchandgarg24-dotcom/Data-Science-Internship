# %%
import pandas as pd

df = pd.read_csv("Data.csv")

print("Dataset loaded successfully ✅")
print("Total customers in dataset:", df.shape[0])
print("Columns available:")
print(df.columns)
# Out:
# Dataset loaded successfully ✅
# Total customers in dataset: 7043
# Columns available:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
print(
    "Objective: Reduce customer churn using insights from exploratory analysis "
    "and predictive machine learning models, while protecting high-value revenue."
)
# Out:
# Objective: Reduce customer churn using insights from exploratory analysis and predictive machine learning models, while protecting high-value revenue.

# %%
print("- Churn rate is significantly higher for 'Month-to-month' contract customers.")
print("- Customers with low tenure (0–12 months) show the highest churn probability.")
print("- High MonthlyCharges are positively correlated with churn.")
print("- Long-tenure customers generally have lower churn, but when they churn, revenue impact is high.")
print("- Contract type, tenure, and MonthlyCharges were top features in the predictive model.")
# Out:
# - Churn rate is significantly higher for 'Month-to-month' contract customers.
# - Customers with low tenure (0–12 months) show the highest churn probability.
# - High MonthlyCharges are positively correlated with churn.
# - Long-tenure customers generally have lower churn, but when they churn, revenue impact is high.
# - Contract type, tenure, and MonthlyCharges were top features in the predictive model.

# %%
print("Segment A: Month-to-month contract customers")
print("Segment B: New customers (tenure < 12 months)")
print("Segment C: High MonthlyCharges customers")
print("Segment D: Long-tenure + high-charge customers predicted to churn")
# Out:
# Segment A: Month-to-month contract customers
# Segment B: New customers (tenure < 12 months)
# Segment C: High MonthlyCharges customers
# Segment D: Long-tenure + high-charge customers predicted to churn

# %%
print(
    "- Offer incentives such as 10–15% discounts or bundled services "
    "to encourage 1-year or 2-year contracts."
)
print(
    "- Target customers identified by the churn prediction model as high risk."
)
# Out:
# - Offer incentives such as 10–15% discounts or bundled services to encourage 1-year or 2-year contracts.
# - Target customers identified by the churn prediction model as high risk.

# %%
print(
    "- Introduce structured onboarding programs during the first 3–6 months."
)
print(
    "- Provide welcome offers, setup assistance, and proactive customer support."
)
# Out:
# - Introduce structured onboarding programs during the first 3–6 months.
# - Provide welcome offers, setup assistance, and proactive customer support.

# %%
print(
    "- Provide personalized pricing plans or loyalty discounts."
)
print(
    "- Offer premium support or value-added services instead of flat discounts."
)
# Out:
# - Provide personalized pricing plans or loyalty discounts.
# - Offer premium support or value-added services instead of flat discounts.

# %%
print(
    "- Deploy the trained churn model to score customers weekly."
)
print(
    "- Flag high-risk customers and route them to retention teams."
)
# Out:
# - Deploy the trained churn model to score customers weekly.
# - Flag high-risk customers and route them to retention teams.

# %%
print("- Targeted email/SMS campaigns for high-risk customers.")
print("- Contract upgrade promotions for month-to-month users.")
print("- Loyalty rewards for long-tenure customers.")
print("- Feedback surveys followed by immediate corrective actions.")
# Out:
# - Targeted email/SMS campaigns for high-risk customers.
# - Contract upgrade promotions for month-to-month users.
# - Loyalty rewards for long-tenure customers.
# - Feedback surveys followed by immediate corrective actions.

# %%
print("Assumptions:")
print("- Current churn rate ≈ 25–27%")
print("- Target churn reduction = 3–5 percentage points")
print("- Retention cost < acquisition cost")

print("\nEstimated Impact:")
print("- Retaining even 3–5% of customers can save hundreds of accounts annually.")
print("- Protects high-value recurring revenue from long-tenure customers.")
print("- Improves customer lifetime value (CLV).")
print("- Reduces customer acquisition costs.")
# Out:
# Assumptions:
# - Current churn rate ≈ 25–27%
# - Target churn reduction = 3–5 percentage points
# - Retention cost < acquisition cost
#
# Estimated Impact:
# - Retaining even 3–5% of customers can save hundreds of accounts annually.
# - Protects high-value recurring revenue from long-tenure customers.
# - Improves customer lifetime value (CLV).
# - Reduces customer acquisition costs.

# %%
print("- Avoid blanket discounts; focus only on high-risk customers.")
print("- Monitor model performance over time.")
print("- Refresh predictions periodically with new data.")
print("- Track churn KPIs after strategy rollout.")
# Out:
# - Avoid blanket discounts; focus only on high-risk customers.
# - Monitor model performance over time.
# - Refresh predictions periodically with new data.
# - Track churn KPIs after strategy rollout.

# %%
print(
    "Adopt a data-driven churn management strategy that combines "
    "predictive modeling with targeted retention offers, focusing on "
    "contract type, tenure, and customer value."
)
# Out:
# Adopt a data-driven churn management strategy that combines predictive modeling with targeted retention offers, focusing on contract type, tenure, and customer value.
