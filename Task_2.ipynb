# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("Data.csv")

print("Dataset loaded successfully ✅")
print("Dataset shape (rows, columns):", df.shape)
# Out:
# Dataset loaded successfully ✅
# Dataset shape (rows, columns): (7043, 21)

# %%
print("Step 3: Cleaning TotalCharges column...")

df["TotalCharges"] = pd.to_numeric(df["TotalCharges"], errors="coerce")

print("Missing values in TotalCharges before filling:")
print(df["TotalCharges"].isnull().sum())

df["TotalCharges"] = df["TotalCharges"].fillna(df["TotalCharges"].median())

print("Missing values in TotalCharges after filling:")
print(df["TotalCharges"].isnull().sum())
# Out:
# Step 3: Cleaning TotalCharges column...
# Missing values in TotalCharges before filling:
# 11
# Missing values in TotalCharges after filling:
# 0

# %%
print("Step 4: Calculating overall churn rate...")

churn_counts = df["Churn"].value_counts()
print("Churn counts:")
print(churn_counts)

churn_rate = (churn_counts["Yes"] / len(df)) * 100
print(f"Overall churn rate: {churn_rate:.2f}%")
# Out:
# Step 4: Calculating overall churn rate...
# Churn counts:
# Churn
# No     5174
# Yes    1869
# Name: count, dtype: int64
# Overall churn rate: 26.54%

# %%
print("Visualizing churn distribution...")

churn_counts.plot(kind="bar")
plt.title("Overall Churn Distribution")
plt.xlabel("Churn")
plt.ylabel("Number of Customers")
plt.show()
# Out:
# Visualizing churn distribution...

# %%
print("Step 5: Customer distribution by Gender...")

gender_dist = df["gender"].value_counts()
print(gender_dist)

gender_dist.plot(kind="bar")
plt.title("Customer Distribution by Gender")
plt.xlabel("Gender")
plt.ylabel("Count")
plt.show()
# Out:
# Step 5: Customer distribution by Gender...
# gender
# Male      3555
# Female    3488
# Name: count, dtype: int64

# %%
print("Step 6: Customer distribution by Partner status...")

partner_dist = df["Partner"].value_counts()
print(partner_dist)

partner_dist.plot(kind="bar")
plt.title("Customer Distribution by Partner Status")
plt.xlabel("Partner")
plt.ylabel("Count")
plt.show()
# Out:
# Step 6: Customer distribution by Partner status...
# Partner
# No     3641
# Yes    3402
# Name: count, dtype: int64

# %%
print("Step 7: Customer distribution by Dependent status...")

dependent_dist = df["Dependents"].value_counts()
print(dependent_dist)

dependent_dist.plot(kind="bar")
plt.title("Customer Distribution by Dependent Status")
plt.xlabel("Dependents")
plt.ylabel("Count")
plt.show()
# Out:
# Step 7: Customer distribution by Dependent status...
# Dependents
# No     4933
# Yes    2110
# Name: count, dtype: int64

# %%
print("Step 8: Analyzing tenure distribution...")

print(df["tenure"].describe())

df["tenure"].plot(kind="hist", bins=30)
plt.title("Tenure Distribution")
plt.xlabel("Tenure (Months)")
plt.ylabel("Number of Customers")
plt.show()
# Out:
# Step 8: Analyzing tenure distribution...
# count    7043.000000
# mean       32.371149
# std        24.559481
# min         0.000000
# 25%         9.000000
# 50%        29.000000
# 75%        55.000000
# max        72.000000
# Name: tenure, dtype: float64

# %%
print("Step 9: Relationship between tenure and churn...")

tenure_churn = df.groupby("Churn")["tenure"].mean()
print("Average tenure by churn status:")
print(tenure_churn)

tenure_churn.plot(kind="bar")
plt.title("Average Tenure by Churn Status")
plt.xlabel("Churn")
plt.ylabel("Average Tenure")
plt.show()
# Out:
# Step 9: Relationship between tenure and churn...
# Average tenure by churn status:
# Churn
# No     37.569965
# Yes    17.979133
# Name: tenure, dtype: float64

# %%
print("Step 10: Churn across Contract types...")

contract_churn = pd.crosstab(df["Contract"], df["Churn"])
print(contract_churn)

contract_churn.plot(kind="bar")
plt.title("Churn by Contract Type")
plt.xlabel("Contract Type")
plt.ylabel("Number of Customers")
plt.show()
# Out:
# Step 10: Churn across Contract types...
# Churn             No   Yes
# Contract
# Month-to-month  2220  1655
# One year        1307   166
# Two year        1647    48

# %%
print("Step 11: Churn across Payment methods...")

payment_churn = pd.crosstab(df["PaymentMethod"], df["Churn"])
print(payment_churn)

payment_churn.plot(kind="bar")
plt.title("Churn by Payment Method")
plt.xlabel("Payment Method")
plt.ylabel("Number of Customers")
plt.show()
# Out:
# Step 11: Churn across Payment methods...
# Churn                        No   Yes
# PaymentMethod
# Bank transfer (automatic)  1286   258
# Credit card (automatic)    1290   232
# Electronic check           1294  1071
# Mailed check               1304   308
